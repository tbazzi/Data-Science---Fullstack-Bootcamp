# %% [markdown]
# # Imports

# %%
import pandas as pd
import sqlalchemy
import psycopg2
# Out:
# /usr/local/lib/python3.6/dist-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %% [markdown]
# # Creér la connexion

# %%
# Update connection string information obtained from the portal


dbname='devbddserver' 
user='jedha@devbddserver' 
host='devbddserver.postgres.database.azure.com'
password='<Mybdd,94>' 
port='5432' 
sslmode='require'

# Construct connection string
conn_string = "host={0} user={1} dbname={2} password={3} sslmode={4}".format(host, user, dbname, password, sslmode)
conn = psycopg2.connect(conn_string) 

#------------------------------------------
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-15-170d7e50204f> in <module>()
#      10 # Construct connection string
#      11 conn_string = "host={0} user={1} dbname={2} password={3} sslmode={4}".format(host, user, dbname, password, sslmode)
# ---> 12 conn = psycopg2.connect(conn_string)
#      13
#      14 #------------------------------------------
#
# /usr/local/lib/python3.6/dist-packages/psycopg2/__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     128
#     129     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 130     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     131     if cursor_factory is not None:
#     132         conn.cursor_factory = cursor_factory
#
# OperationalError: FATAL:  no pg_hba.conf entry for host "34.73.62.76", user "jedha", database "devbddserver", SSL on

# %%
data = [
    {"Col1": 1, "Col2": "A"},
    {"Col1": 2, "Col2": "B"},
    {"Col1": 3, "Col2": "C"}
]

df_test = pd.DataFrame(data)

# %% [markdown]
# # Charger des données

# %%
df_test.to_sql("table_1", engine, index=False, if_exists="replace")

# %% [markdown]
# # Récupérer des données

# %%
df_test = pd.read_sql("SELECT * FROM table_1", engine)

# %% [markdown]
# # Ressources

# %%
print("Doc Microsoft pour Azure Postgres : ")

print("https://docs.microsoft.com/fr-fr/azure/postgresql/quickstart-create-server-database-portal")
# Out:
# Doc Microsoft pour Azure Postgres :
# https://docs.microsoft.com/fr-fr/azure/postgresql/quickstart-create-server-database-portal

# %%
print("Commande de connexion depuis la console Azure : ")

print("psql --host=bddserverstudent.postgres.database.azure.com --port=5432 --username=jedha@bddserverstudent --dbname=postgres")
# Out:
# Commande de connexion depuis la console :
# psql --host=bddserverstudent.postgres.database.azure.com --port=5432 --username=jedha@bddserverstudent --dbname=postgres

# %%
psql --host=bddserverstudent.postgres.database.azure.com --port=5432 --username=admission@bddserverstudent --dbname=postgres
